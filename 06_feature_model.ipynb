# %%
# !pip install xgboost
# !pip install pyarrow

# %%
# !pip install pycaret[analysis]

# %%
# !pip install shap

# %%
# !pip install pycaret --ignore-installed llvmlite numba

# %%
from pycaret.classification import *

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gc
import xgboost as xgb
root = 'C:/Users/Pratham/Documents/GitHub/instacart-customer-purchase-prediction/data/'
from sklearn.neural_network import MLPClassifier
pd.set_option('display.max_rows', None)  # Display all rows
pd.set_option('display.max_columns', None)  # Display all columns

# %%
order_products = pd.read_parquet(root + 'feature_engineer_dataset.parquet')

# %%
order_products.shape
# Out:
# (1384617, 22)

# %%
# filter data where eval_set = 'train'

order_products = order_products[order_products.eval_set == 'train']

# %%
order_products.shape
# Out:
# (1384617, 22)

# %%
order_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1384617 entries, 0 to 1384616
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   order_id                         1384617 non-null  int32
#  1   product_id                       1384617 non-null  int32
#  2   add_to_cart_order                1384617 non-null  int16
#  3   reordered                        1384617 non-null  int8
#  4   product_name                     1384617 non-null  object
#  5   aisle_id                         1384617 non-null  int16
#  6   department_id                    1384617 non-null  int8
#  7   aisle                            1384617 non-null  object
#  8   department                       1384617 non-null  object
#  9   user_id                          1384617 non-null  int32
#  10  eval_set                         1384617 non-null  object
#  11  order_number                     1384617 non-null  int8
#  12  order_dow                        1384617 non-null  int8
#  13  order_hour_of_day                1384617 non-null  int8
#  14  days_since_prior_order           1384617 non-null  float32
#  15  total_orders_by_user             1384617 non-null  int8
#  16  user_reorder_percentage          1384617 non-null  float64
#  17  user_avg_days_since_prior_order  1384617 non-null  float32
#  18  user_most_frequent_order_dow     1384617 non-null  int8
#  19  user_most_frequent_order_hour    1384617 non-null  int8
#  20  total_times_product_reordered    1384617 non-null  float64
#  21  product_reorder_percentage       1384617 non-null  float64
# dtypes: float32(2), float64(3), int16(2), int32(3), int8(8), object(4)
# memory usage: 116.2+ MB

# %%
order_products.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  \
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1
#
#                                     product_name  aisle_id  department_id  \
# 0                               Bulgarian Yogurt       120             16
# 1  Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# 2                          Organic Celery Hearts        83              4
# 3                                 Cucumber Kirby        83              4
# 4           Lightly Smoked Sardines in Olive Oil        95             15
#
#                   aisle    department  user_id eval_set  order_number  \
# 0                yogurt    dairy eggs   112108    train             4
# 1  other creams cheeses    dairy eggs   112108    train             4
# 2      fresh vegetables       produce   112108    train             4
# 3      fresh vegetables       produce   112108    train             4
# 4   canned meat seafood  canned goods   112108    train             4
#
#    order_dow  order_hour_of_day  days_since_prior_order  total_orders_by_user  \
# 0          4                 10                     9.0                     3
# 1          4                 10                     9.0                     3
# 2          4                 10                     9.0                     3
# 3          4                 10                     9.0                     3
# 4          4                 10                     9.0                     3
#
#    user_reorder_percentage  user_avg_days_since_prior_order  \
# 0                 0.428571                        10.076923
# 1                 0.428571                        10.076923
# 2                 0.428571                        10.076923
# 3                 0.428571                        10.076923
# 4                 0.428571                        10.076923
#
#    user_most_frequent_order_dow  user_most_frequent_order_hour  \
# 0                             1                             10
# 1                             1                             10
# 2                             1                             10
# 3                             1                             10
# 4                             1                             10
#
#    total_times_product_reordered  product_reorder_percentage
# 0                          101.0                    0.619632
# 1                         3192.0                    0.713775
# 2                        12498.0                    0.524553
# 3                        67313.0                    0.691702
# 4                          312.0                    0.477795

# %%
exp_clf = setup(order_products, target = 'reordered',session_id = 2 , fold=3, max_encoding_ohe=100,memory=False, ignore_features=['aisle_id','order_id', 'product_id', 'user_id','department_id', 'eval_set'],categorical_features=['aisle', 'department','product_name','order_dow','order_hour_of_day'],numeric_imputation=0)
# Out:
# <style type="text/css">
# #T_571be_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_571be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_571be_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_571be_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_571be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_571be_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_571be_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_571be_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_571be_row1_col1" class="data row1 col1" >reordered</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_571be_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_571be_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_571be_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_571be_row3_col1" class="data row3 col1" >(1384617, 22)</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_571be_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_571be_row4_col1" class="data row4 col1" >(1384617, 65)</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_571be_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_571be_row5_col1" class="data row5 col1" >(969231, 65)</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_571be_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_571be_row6_col1" class="data row6 col1" >(415386, 65)</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_571be_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_571be_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_571be_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_571be_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_571be_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_571be_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_571be_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_571be_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_571be_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_571be_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_571be_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_571be_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_571be_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_571be_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_571be_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_571be_row14_col1" class="data row14 col1" >100</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_571be_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_571be_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_571be_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_571be_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_571be_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_571be_row17_col1" class="data row17 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_571be_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_571be_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_571be_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_571be_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_571be_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_571be_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_571be_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_571be_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_571be_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_571be_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_571be_row22_col1" class="data row22 col1" >4763</td>
#     </tr>
#   </tbody>
# </table>

# %%
prep_pipe = get_config('X_train_transformed') 
prep_pipe.head()
# Out:
#         add_to_cart_order  product_name     aisle  department_produce  \
# 268293                1.0      0.625850  0.723546                 1.0
# 908635                6.0      0.793462  0.735644                 1.0
# 90259                 2.0      0.715151  0.646523                 0.0
# 358944                5.0      0.552419  0.414222                 0.0
# 16928                 4.0      0.398704  0.466133                 0.0
#
#         department_beverages  department_pantry  department_household  \
# 268293                   0.0                0.0                   0.0
# 908635                   0.0                0.0                   0.0
# 90259                    1.0                0.0                   0.0
# 358944                   0.0                1.0                   0.0
# 16928                    0.0                0.0                   1.0
#
#         department_personal care  department_canned goods  department_frozen  \
# 268293                       0.0                      0.0                0.0
# 908635                       0.0                      0.0                0.0
# 90259                        0.0                      0.0                0.0
# 358944                       0.0                      0.0                0.0
# 16928                        0.0                      0.0                0.0
#
#         department_dairy eggs  department_breakfast  department_snacks  \
# 268293                    0.0                   0.0                0.0
# 908635                    0.0                   0.0                0.0
# 90259                     0.0                   0.0                0.0
# 358944                    0.0                   0.0                0.0
# 16928                     0.0                   0.0                0.0
#
#         department_meat seafood  department_dry goods pasta  \
# 268293                      0.0                         0.0
# 908635                      0.0                         0.0
# 90259                       0.0                         0.0
# 358944                      0.0                         0.0
# 16928                       0.0                         0.0
#
#         department_bakery  department_deli  department_pets  department_other  \
# 268293                0.0              0.0              0.0               0.0
# 908635                0.0              0.0              0.0               0.0
# 90259                 0.0              0.0              0.0               0.0
# 358944                0.0              0.0              0.0               0.0
# 16928                 0.0              0.0              0.0               0.0
#
#         department_bulk  department_babies  department_alcohol  \
# 268293              0.0                0.0                 0.0
# 908635              0.0                0.0                 0.0
# 90259               0.0                0.0                 0.0
# 358944              0.0                0.0                 0.0
# 16928               0.0                0.0                 0.0
#
#         department_missing  department_international  order_number  \
# 268293                 0.0                       0.0           4.0
# 908635                 0.0                       0.0           6.0
# 90259                  0.0                       0.0           7.0
# 358944                 0.0                       0.0           5.0
# 16928                  0.0                       0.0          15.0
#
#         order_dow_5.0  order_dow_0.0  order_dow_1.0  order_dow_4.0  \
# 268293            1.0            0.0            0.0            0.0
# 908635            0.0            1.0            0.0            0.0
# 90259             1.0            0.0            0.0            0.0
# 358944            0.0            0.0            1.0            0.0
# 16928             1.0            0.0            0.0            0.0
#
#         order_dow_3.0  order_dow_2.0  order_dow_6.0  order_hour_of_day_17.0  \
# 268293            0.0            0.0            0.0                     1.0
# 908635            0.0            0.0            0.0                     0.0
# 90259             0.0            0.0            0.0                     0.0
# 358944            0.0            0.0            0.0                     0.0
# 16928             0.0            0.0            0.0                     0.0
#
#         order_hour_of_day_13.0  order_hour_of_day_14.0  order_hour_of_day_8.0  \
# 268293                     0.0                     0.0                    0.0
# 908635                     1.0                     0.0                    0.0
# 90259                      0.0                     1.0                    0.0
# 358944                     0.0                     0.0                    1.0
# 16928                      0.0                     0.0                    0.0
#
#         order_hour_of_day_18.0  order_hour_of_day_9.0  order_hour_of_day_10.0  \
# 268293                     0.0                    0.0                     0.0
# 908635                     0.0                    0.0                     0.0
# 90259                      0.0                    0.0                     0.0
# 358944                     0.0                    0.0                     0.0
# 16928                      1.0                    0.0                     0.0
#
#         order_hour_of_day_16.0  order_hour_of_day_20.0  \
# 268293                     0.0                     0.0
# 908635                     0.0                     0.0
# 90259                      0.0                     0.0
# 358944                     0.0                     0.0
# 16928                      0.0                     0.0
#
#         order_hour_of_day_12.0  order_hour_of_day_6.0  order_hour_of_day_19.0  \
# 268293                     0.0                    0.0                     0.0
# 908635                     0.0                    0.0                     0.0
# 90259                      0.0                    0.0                     0.0
# 358944                     0.0                    0.0                     0.0
# 16928                      0.0                    0.0                     0.0
#
#         order_hour_of_day_11.0  order_hour_of_day_4.0  order_hour_of_day_15.0  \
# 268293                     0.0                    0.0                     0.0
# 908635                     0.0                    0.0                     0.0
# 90259                      0.0                    0.0                     0.0
# 358944                     0.0                    0.0                     0.0
# 16928                      0.0                    0.0                     0.0
#
#         order_hour_of_day_7.0  order_hour_of_day_22.0  order_hour_of_day_1.0  \
# 268293                    0.0                     0.0                    0.0
# 908635                    0.0                     0.0                    0.0
# 90259                     0.0                     0.0                    0.0
# 358944                    0.0                     0.0                    0.0
# 16928                     0.0                     0.0                    0.0
#
#         order_hour_of_day_21.0  order_hour_of_day_2.0  order_hour_of_day_23.0  \
# 268293                     0.0                    0.0                     0.0
# 908635                     0.0                    0.0                     0.0
# 90259                      0.0                    0.0                     0.0
# 358944                     0.0                    0.0                     0.0
# 16928                      0.0                    0.0                     0.0
#
#         order_hour_of_day_5.0  order_hour_of_day_0.0  order_hour_of_day_3.0  \
# 268293                    0.0                    0.0                    0.0
# 908635                    0.0                    0.0                    0.0
# 90259                     0.0                    0.0                    0.0
# 358944                    0.0                    0.0                    0.0
# 16928                     0.0                    0.0                    0.0
#
#         days_since_prior_order  total_orders_by_user  user_reorder_percentage  \
# 268293                     0.0                   3.0                 0.000000
# 908635                    19.0                   5.0                 0.333333
# 90259                     19.0                   6.0                 0.243243
# 358944                    30.0                   4.0                 0.217391
# 16928                      4.0                  14.0                 0.446602
#
#         user_avg_days_since_prior_order  user_most_frequent_order_dow  \
# 268293                        30.000000                           5.0
# 908635                        12.793103                           0.0
# 90259                         14.709678                           0.0
# 358944                        20.294117                           6.0
# 16928                         19.837988                           1.0
#
#         user_most_frequent_order_hour  total_times_product_reordered  \
# 268293                           14.0                         3090.0
# 908635                           10.0                        57201.0
# 90259                            10.0                         4104.0
# 358944                           18.0                         3514.0
# 16928                            22.0                          569.0
#
#         product_reorder_percentage
# 268293                    0.586338
# 908635                    0.761006
# 90259                     0.665370
# 358944                    0.510979
# 16928                     0.302338

# %%
#  create custom model pycaret
model=create_model( xgb.XGBClassifier(class_weight='balanced'))
# Out:
# <style type="text/css">
# #T_f9ef4_row3_col0, #T_f9ef4_row3_col1, #T_f9ef4_row3_col2, #T_f9ef4_row3_col3, #T_f9ef4_row3_col4, #T_f9ef4_row3_col5, #T_f9ef4_row3_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f9ef4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9ef4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f9ef4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f9ef4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f9ef4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f9ef4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f9ef4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f9ef4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9ef4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9ef4_row0_col0" class="data row0 col0" >0.7075</td>
#       <td id="T_f9ef4_row0_col1" class="data row0 col1" >0.7619</td>
#       <td id="T_f9ef4_row0_col2" class="data row0 col2" >0.8045</td>
#       <td id="T_f9ef4_row0_col3" class="data row0 col3" >0.7329</td>
#       <td id="T_f9ef4_row0_col4" class="data row0 col4" >0.7670</td>
#       <td id="T_f9ef4_row0_col5" class="data row0 col5" >0.3763</td>
#       <td id="T_f9ef4_row0_col6" class="data row0 col6" >0.3793</td>
#     </tr>
#     <tr>
#       <th id="T_f9ef4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9ef4_row1_col0" class="data row1 col0" >0.7071</td>
#       <td id="T_f9ef4_row1_col1" class="data row1 col1" >0.7614</td>
#       <td id="T_f9ef4_row1_col2" class="data row1 col2" >0.8051</td>
#       <td id="T_f9ef4_row1_col3" class="data row1 col3" >0.7322</td>
#       <td id="T_f9ef4_row1_col4" class="data row1 col4" >0.7669</td>
#       <td id="T_f9ef4_row1_col5" class="data row1 col5" >0.3752</td>
#       <td id="T_f9ef4_row1_col6" class="data row1 col6" >0.3783</td>
#     </tr>
#     <tr>
#       <th id="T_f9ef4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f9ef4_row2_col0" class="data row2 col0" >0.7074</td>
#       <td id="T_f9ef4_row2_col1" class="data row2 col1" >0.7621</td>
#       <td id="T_f9ef4_row2_col2" class="data row2 col2" >0.8067</td>
#       <td id="T_f9ef4_row2_col3" class="data row2 col3" >0.7319</td>
#       <td id="T_f9ef4_row2_col4" class="data row2 col4" >0.7675</td>
#       <td id="T_f9ef4_row2_col5" class="data row2 col5" >0.3754</td>
#       <td id="T_f9ef4_row2_col6" class="data row2 col6" >0.3786</td>
#     </tr>
#     <tr>
#       <th id="T_f9ef4_level0_row3" class="row_heading level0 row3" >Mean</th>
#       <td id="T_f9ef4_row3_col0" class="data row3 col0" >0.7073</td>
#       <td id="T_f9ef4_row3_col1" class="data row3 col1" >0.7618</td>
#       <td id="T_f9ef4_row3_col2" class="data row3 col2" >0.8054</td>
#       <td id="T_f9ef4_row3_col3" class="data row3 col3" >0.7323</td>
#       <td id="T_f9ef4_row3_col4" class="data row3 col4" >0.7671</td>
#       <td id="T_f9ef4_row3_col5" class="data row3 col5" >0.3757</td>
#       <td id="T_f9ef4_row3_col6" class="data row3 col6" >0.3787</td>
#     </tr>
#     <tr>
#       <th id="T_f9ef4_level0_row4" class="row_heading level0 row4" >Std</th>
#       <td id="T_f9ef4_row4_col0" class="data row4 col0" >0.0002</td>
#       <td id="T_f9ef4_row4_col1" class="data row4 col1" >0.0003</td>
#       <td id="T_f9ef4_row4_col2" class="data row4 col2" >0.0009</td>
#       <td id="T_f9ef4_row4_col3" class="data row4 col3" >0.0004</td>
#       <td id="T_f9ef4_row4_col4" class="data row4 col4" >0.0002</td>
#       <td id="T_f9ef4_row4_col5" class="data row4 col5" >0.0005</td>
#       <td id="T_f9ef4_row4_col6" class="data row4 col6" >0.0004</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(model, plot = 'confusion_matrix')

# %%
plot_model(model)

# %%
interpret_model(model)
